# %%
import pandas as pd

# %%
df=pd.read_csv('words.csv')

# %%
df.loc[df['類語'].isna(),'類語']="['']"

# %%
df
# Out:
#                                           単語                    訳語  \
# 0                                 exacerbate              ['悪化する']
# 1                          Before preceeding            ['先に進む前に']
# 2                                  piggyback               ['おんぶ']
# 3                                  auxiliary                ['補助']
# 4                                 stochastic              ['確率的な']
# 5                                 negligible             ['無視できる']
# 6                                 may have V                   NaN
# 7                         the team I support                   NaN
# 8                                      dizzy              ['クラクラ']
# 9                         There be no a noun                   NaN
# 10                                 tractable             ['扱いやすい']
# 11                           lend oneself to              ['に役立つ']
# 12                                  preclude              ['排除する']
# ...

# %%
df.to_csv('words.csv',index=False,encoding='utf-8')

# %%
df.loc[df['タイプ']=='覚えたい表現（訳語いらない）','タイプ']="覚えたい表現"

# %%
import re
japa='feafa '

# %%
japa=re.sub('(\s*)','',japa)
japa=japa.split('、')

# %%
japa
# Out:
# ['feafa']
